# %% [markdown]
# <a href="https://colab.research.google.com/github/BuretGriffin/Moringa_Data_Science_Prep_W3_Independent_Project_2022_03_BURET_GRIFFIN.ipynb/blob/main/Moringa_Data_Science_Prep_W3_Independent_Project_2022_03_BURET_GRIFFIN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
df1 = pd.read_csv('Telcom_dataset.csv')

df1.head()
# Out:
#   PRODUTC  VALUE               DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0   Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1     sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2     sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3   Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4   Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
#
#    DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1a49f8b0ded9de6     19e2e     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1  93343ba6e41af95     19e2e     19e2e  /+cKZKIp41  /+cKZKIp41
# 2  7aacc9709ce0a20     19e2e     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3  6af4a60e74c91d3     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4  02aa736ee555d5c     19e2e     19e2e  051KhYDCpv  051KhYDCpv

# %%
df2 = pd.read_csv('Telcom_dataset2.csv')

df2.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME CELL_ON_SITE      DW_A_NUMBER  \
# 0     sms      0  2012-05-07 23:02:06.0            2  32255675c3b6fe3
# 1   Voice      0  2012-05-07 23:03:44.0            1  ff16d6ac74c1c64
# 2     sms      0  2012-05-07 23:04:06.0            0  98d9f2fb5ff624b
# 3   Voice     37  2012-05-07 23:04:48.0            1  3f9c8a33ec7be1f
# 4     sms     25  2012-05-07 23:04:58.0            1  7bcccc03adf3864
#
#        DW_B_NUMBER COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1aa7ae01386e9fb     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 1  87d87309c15a8c9     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 2  93343ba6e41af95     19e2e     19e2e  +laSrk7g6q  +laSrk7g6q
# 3  7d05a38f89c49d8     19e2e     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4  56a5d5430d2fa86     19e2e     19e2e  +bO+qkSonO  +bO+qkSonO

# %%
df3 = pd.read_csv('Telcom_dataset3.csv')

df3.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0   Voice     61  2012-05-08 23:01:28.0            2  966f68353622feb
# 1     sms      0  2012-05-08 23:01:31.0            1  a0a597384c612d7
# 2   Voice     10  2012-05-08 23:02:59.0            1  5441a9a58c97132
# 3     sms      0  2012-05-08 23:03:04.0            0  8ab8b9ed6989f61
# 4   Voice     22  2012-05-08 23:03:16.0            4  52662a62b199334
#
#    DW_B_NUMBER_INT COUNTRY_A COUNTRY_B      CELLID     SIET_ID
# 0  ffd53a3bb2db6f1     19e2e     19e2e  +38u2u/rfx  +38u2u/rfx
# 1  cf3b218f1dde792     19e2e     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2  52f8b299515b9b7     19e2e     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3  e09e736e46c5c3d     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4  2186273faab4602     19e2e     19e2e  /eeMklgyJA  /eeMklgyJA

# %%
df4 = pd.read_csv('cells_geo.csv',delimiter=';', names = ['City','Status','Locality','Geographical_Zone','Zone_Name','Longitude','Latitude','Region','Area','Cell_ID','Site_ID'])

df4.head()
# Out:
#         City      Status      Locality Geographical_Zone Zone_Name  \
# NaN   VILLES      STATUS  LOCALISATION        DECOUPZONE  ZONENAME
# 0.0   ADJAME  In Service       ABIDJAN      "Abidjan_EST  AGBANNEW
# 1.0   ADJAME  In Service       ABIDJAN      "Abidjan_EST  AGBANNEW
# 2.0   ADJAME  In Service       ABIDJAN      "Abidjan_EST  AGBANNEW
# 3.0  ASSINIE  In Service     INTERIEUR         Grand-EST  ASSINIE"
#
#              Longitude          Latitude     Region  Area     Cell_ID  \
# NaN          LONGITUDE          LATITUDE     REGION  AREA     CELL_ID
# 0.0  -4.00066666666667  5.36819444444444     LAGUNE   NaN  fbb2e75af3
# 1.0  -4.00066666666667  5.36819444444444     LAGUNE   NaN  1502501d78
# 2.0  -4.00066666666667  5.36819444444444     LAGUNE   NaN  0c2e182a0c
# 3.0  -3.48846666666667  5.15876111111111  SUD COMOE   NaN  69bdfc69fd
#
#         Site_ID
# NaN   SITE_CODE
# 0.0  0bb492ef17
# 1.0  0bb492ef17
# 2.0  0bb492ef17
# 3.0  8a1e6ce31f

# %%
df5 = pd.read_excel('cells_geo_description.xlsx')

df5.head()
# Out:
#     Column name        Description  Format
# 0        VILLES               City  String
# 1        STATUS  In Service or not  String
# 2  LOCALISATION  in ABIDJAN or not  String
# 3    DECOUPZONE  Geographical Zone  String
# 4      ZONENAME       Name of Zone  String

# %%
df6 = pd.read_excel('CDR_description.xlsx')

df6.head()
# Out:
#        Column name                                        Description   Format
# 0          PRODUCT                                       Voice or SMS   String
# 1            VALUE                                      Billing price  Integer
# 2        DATE_TIME               Time in format yyyy-MM-dd hh:mm:ss.0   String
# 3     CELL_ON_SITE  Which cell in the site was used (not needed here)  Integer
# 4  DW_A_NUMBER_INT  Anonymized phone number of the person for whic...   String

# %% [markdown]
# # **DATA** **CLEANING**

# %%
df4. drop(df4. index[0])
# Out:
#             City      Status   Locality Geographical_Zone  \
# 0.0       ADJAME  In Service    ABIDJAN      "Abidjan_EST
# 1.0       ADJAME  In Service    ABIDJAN      "Abidjan_EST
# 2.0       ADJAME  In Service    ABIDJAN      "Abidjan_EST
# 3.0      ASSINIE  In Service  INTERIEUR         Grand-EST
# 4.0      ASSINIE  In Service  INTERIEUR         Grand-EST
# ...          ...         ...        ...               ...
# 3969.0  ZUENOULA  In Service  INTERIEUR        Grand-NORD
# 3970.0  ZUENOULA  In Service  INTERIEUR        Grand-NORD
# 3971.0  ZUENOULA  In Service  INTERIEUR        Grand-NORD
# 3972.0  ZUENOULA  In Service  INTERIEUR        Grand-NORD
# 3973.0  ZUENOULA  In Service  INTERIEUR        Grand-NORD
#
#                   Zone_Name          Longitude          Latitude     Region  \
# 0.0                AGBANNEW  -4.00066666666667  5.36819444444444     LAGUNE
# 1.0                AGBANNEW  -4.00066666666667  5.36819444444444     LAGUNE
# ...

# %%
df1.columns
  
df1.columns = map(str.lower, df1.columns)
df1.columns

columns = ['product', 'value', 'date_time', 'cell_on_site', 'dw_a_number_int',
'dw_b_number_int', 'country_a', 'country_b', 'cell_id', 'site_id']
df1.columns = columns
df1.head()
# Out:
#   product  value              date_time cell_on_site  dw_a_number_int  \
# 0   Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1     sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2     sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3   Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4   Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
#
#    dw_b_number_int country_a country_b     cell_id     site_id
# 0  1a49f8b0ded9de6     19e2e     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1  93343ba6e41af95     19e2e     19e2e  /+cKZKIp41  /+cKZKIp41
# 2  7aacc9709ce0a20     19e2e     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3  6af4a60e74c91d3     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4  02aa736ee555d5c     19e2e     19e2e  051KhYDCpv  051KhYDCpv

# %%
df2.columns = columns
df2.head()
# Out:
#   product  value              date_time cell_on_site  dw_a_number_int  \
# 0     sms      0  2012-05-07 23:02:06.0            2  32255675c3b6fe3
# 1   Voice      0  2012-05-07 23:03:44.0            1  ff16d6ac74c1c64
# 2     sms      0  2012-05-07 23:04:06.0            0  98d9f2fb5ff624b
# 3   Voice     37  2012-05-07 23:04:48.0            1  3f9c8a33ec7be1f
# 4     sms     25  2012-05-07 23:04:58.0            1  7bcccc03adf3864
#
#    dw_b_number_int country_a country_b     cell_id     site_id
# 0  1aa7ae01386e9fb     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 1  87d87309c15a8c9     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 2  93343ba6e41af95     19e2e     19e2e  +laSrk7g6q  +laSrk7g6q
# 3  7d05a38f89c49d8     19e2e     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4  56a5d5430d2fa86     19e2e     19e2e  +bO+qkSonO  +bO+qkSonO

# %%
df3.columns = columns
df3.head()
# Out:
#   product  value              date_time cell_on_site  dw_a_number_int  \
# 0   Voice     61  2012-05-08 23:01:28.0            2  966f68353622feb
# 1     sms      0  2012-05-08 23:01:31.0            1  a0a597384c612d7
# 2   Voice     10  2012-05-08 23:02:59.0            1  5441a9a58c97132
# 3     sms      0  2012-05-08 23:03:04.0            0  8ab8b9ed6989f61
# 4   Voice     22  2012-05-08 23:03:16.0            4  52662a62b199334
#
#    dw_b_number_int country_a country_b     cell_id     site_id
# 0  ffd53a3bb2db6f1     19e2e     19e2e  +38u2u/rfx  +38u2u/rfx
# 1  cf3b218f1dde792     19e2e     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2  52f8b299515b9b7     19e2e     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3  e09e736e46c5c3d     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4  2186273faab4602     19e2e     19e2e  /eeMklgyJA  /eeMklgyJA

# %%
df_combine = pd.concat([df1,df2,df3], ignore_index = 1)
df_combine.tail()
# Out:
#       product  value              date_time cell_on_site  dw_a_number_int  \
# 14998   Voice      0  2012-05-09 00:01:43.0            3  467333ade2b4b9c
# 14999   Voice     62  2012-05-09 00:01:43.0            1  e077a6b74c5053c
# 15000   Voice     32  2012-05-09 00:01:43.0            1  77f53c39d27c050
# 15001   Voice     30  2012-05-09 00:01:43.0            2  672ce74c418aa7a
# 15002   Voice     60  2012-05-09 00:01:43.0            2  6edeb4c55714650
#
#        dw_b_number_int country_a country_b     cell_id     site_id
# 14998  0ab2acd804d01fe     19e2e     19e2e  2aa04dcab7  f7d63a29e5
# 14999  4c8098eb6ea1a41     19e2e     19e2e  7f1f2f889f  b4ddb9e93c
# 15000  9d064f013e2cab2     19e2e     19e2e  a4731e780e  d68260ef50
# 15001  f9ff5af59cf0d68     19e2e     19e2e  98ed726da2  b4130b54ab
# 15002  7e60838216482a7     19e2e     19e2e  1c11a2fcbb  6d70dae094

# %%
#split the datetime column into different columns
df_combine[['date', 'time']] = df_combine.date_time.str.split(expand=True)
df_combine.head()
# Out:
#   product  value              date_time cell_on_site  dw_a_number_int  \
# 0   Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1     sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2     sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3   Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4   Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
#
#    dw_b_number_int country_a country_b     cell_id     site_id        date  \
# 0  1a49f8b0ded9de6     19e2e     19e2e  /TJNe+Mmtu  /TJNe+Mmtu  2012-05-06
# 1  93343ba6e41af95     19e2e     19e2e  /+cKZKIp41  /+cKZKIp41  2012-05-06
# 2  7aacc9709ce0a20     19e2e     19e2e  /u0FSD+ahi  /u0FSD+ahi  2012-05-06
# 3  6af4a60e74c91d3     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3  2012-05-06
# 4  02aa736ee555d5c     19e2e     19e2e  051KhYDCpv  051KhYDCpv  2012-05-06
#
#          time
# 0  23:04:37.0
# 1  23:05:25.0
# 2  23:05:41.0
# 3  23:05:42.0
# 4  23:06:29.0

# %% [markdown]
# DROPPING AND DELETING UNNECCESAARY COLUMNS

# %% [markdown]
# **DATA UNDERSTANDING**
#
# 1.GEO DATA

# %%
#lets get the information and decriptive statistics of each dataset
#
print(df4.info())
print(df4.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 3975 entries, nan to 3973.0
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               3975 non-null   object
#  1   Status             3908 non-null   object
#  2   Locality           3975 non-null   object
#  3   Geographical_Zone  3975 non-null   object
#  4   Zone_Name          3969 non-null   object
#  5   Longitude          3975 non-null   object
#  6   Latitude           3975 non-null   object
#  7   Region             3975 non-null   object
#  8   Area               3952 non-null   object
#  9   Cell_ID            3975 non-null   object
#  10  Site_ID            3975 non-null   object
# dtypes: object(11)
# memory usage: 501.7+ KB
# None
#           City      Status   Locality Geographical_Zone             Zone_Name  \
# count     3975        3908       3975              3975                  3969
# ...

# %%
# LETS FIND THE UNIQUE VALUS IN THE CELLS GEO DATASET
print ("There are ", df4.Locality.nunique(), "Unique Localities  " "out of " , df4.Locality.count())
print ("There are ", df4.Area.nunique(), "Unique Area  out of " , df4.Area.count())
print ("There are  ", df4.Geographical_Zone.nunique(), "Unique Geographical_Zone out of " , df4.Geographical_Zone.count())
print ("There are ", df4.Region.nunique(), "Unique Regions  out of " , df4.Region.count())
print ("There are ", df4.City.nunique(), "Unique cities out of " , df4.City.count())
print ("There are ", df4.Site_ID.nunique(), "Unique Site_Id  out of " , df4.Site_ID.count())
print ("There are", df4.Cell_ID.nunique(), " Unique Cell_ID out of " , df4.Cell_ID.count())
# Out:
# There are  3 Unique Localities  out of  3975
# There are  7 Unique Area  out of  3952
# There are   16 Unique Geographical_Zone out of  3975
# There are  20 Unique Regions  out of  3975
# There are  505 Unique cities out of  3975
# There are  1030 Unique Site_Id  out of  3975
# There are 3917  Unique Cell_ID out of  3975

# %%
# lets find out the statues
list(df4.Status.unique())
# Out:
# ['STATUS', 'In Service', nan]

# %%
#finding out the null values
print(df4.isnull().sum())
# Out:
# City                  0
# Status               67
# Locality              0
# Geographical_Zone     0
# Zone_Name             6
# Longitude             0
# Latitude              0
# Region                0
# Area                 23
# Cell_ID               0
# Site_ID               0
# dtype: int64

# %% [markdown]
# 2.CDR DATASET

# %%
# DESCRIPTION
print("CDR Information")
print(df6.info())
print("CDR Statistics")
print(df6.describe())
# Out:
# CDR Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Column name  10 non-null     object
#  1   Description  10 non-null     object
#  2   Format       10 non-null     object
# dtypes: object(3)
# memory usage: 368.0+ bytes
# None
# CDR Statistics
#        Column name   Description  Format
# count           10            10      10
# unique          10            10       2
# top        PRODUCT  Voice or SMS  String
# freq             1             1       8

# %%
# NULL VALUES
print("Null Values in Cells Dataset")
print(df6.isnull().sum())
# Out:
# Null Values in Cells Dataset
# Column name    0
# Description    0
# Format         0
# dtype: int64

# %%
#GEO DESCRIPTION Dataframe Information and it's descriptive statistics
print("Geo DESCRIPTION Information")
print(df5.info())
print("GEO DESCRIPTION Statistics")
print(df5.describe())
print("GEO DESCRIPTION Dataset")
print(df5.isnull().sum())
# Out:
# Geo DESCRIPTION Information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Column name  11 non-null     object
#  1   Description  11 non-null     object
#  2   Format       11 non-null     object
# dtypes: object(3)
# memory usage: 392.0+ bytes
# None
# GEO DESCRIPTION Statistics
#        Column name Description  Format
# count           11          11      11
# unique          11          11       2
# top         VILLES        City  String
# freq             1           1       9
# GEO DESCRIPTION Dataset
# Column name    0
# Description    0
# Format         0
# dtype: int64

# %%
#Check duplicates
print(df_combine[df_combine.duplicated(keep=False)])
# Out:
#       product  value              date_time cell_on_site  dw_a_number_int  \
# 765       sms      0  2012-05-07 00:00:03.0            0  fc29d09837d792a
# 769       sms     25  2012-05-07 00:00:03.0            1  ff24e18fedc9554
# 793       sms      0  2012-05-07 00:00:03.0            0  fc29d09837d792a
# 794       sms     25  2012-05-07 00:00:03.0            1  ff24e18fedc9554
# 795     Voice      0  2012-05-07 00:00:04.0            1  1a2b54695968d46
# ...       ...    ...                    ...          ...              ...
# 14964     sms      0  2012-05-09 00:01:42.0            0  dba6e400f5c08c5
# 14965     sms      0  2012-05-09 00:01:43.0            0  a1674d96f3d7691
# 14966   Voice     32  2012-05-09 00:01:43.0            1  77f53c39d27c050
# 14971     sms      0  2012-05-09 00:01:43.0            0  a1674d96f3d7691
# 15000   Voice     32  2012-05-09 00:01:43.0            1  77f53c39d27c050
#
#        dw_b_number_int country_a country_b     cell_id     site_id  \
# ...

# %% [markdown]
# combine cdr ang geo tables

# %%
df_cdrcombine = pd.concat([df4,df5,df6], axis=0)
df_cdrcombine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 3996 entries, nan to 9.0
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               3975 non-null   object
#  1   Status             3908 non-null   object
#  2   Locality           3975 non-null   object
#  3   Geographical_Zone  3975 non-null   object
#  4   Zone_Name          3969 non-null   object
#  5   Longitude          3975 non-null   object
#  6   Latitude           3975 non-null   object
#  7   Region             3975 non-null   object
#  8   Area               3952 non-null   object
#  9   Cell_ID            3975 non-null   object
#  10  Site_ID            3975 non-null   object
#  11  Column name        21 non-null     object
#  12  Description        21 non-null     object
#  13  Format             21 non-null     object
# dtypes: object(14)
# memory usage: 468.3+ KB

# %%
df_combine_cleaned = df_combine.drop(columns = ['country_a' ,	'country_b' ,'cell_on_site',"site_id",])
df_combine_cleaned.head()
# Out:
#   product  value              date_time  dw_a_number_int  dw_b_number_int  \
# 0   Voice      0  2012-05-06 23:04:37.0  49fae048b547780  1a49f8b0ded9de6
# 1     sms      0  2012-05-06 23:05:25.0  7a54a6eaee19e65  93343ba6e41af95
# 2     sms     25  2012-05-06 23:05:41.0  6008887b0207d82  7aacc9709ce0a20
# 3   Voice     56  2012-05-06 23:05:42.0  7370032e20f4e96  6af4a60e74c91d3
# 4   Voice     14  2012-05-06 23:06:29.0  966ba4656e38e62  02aa736ee555d5c
#
#       cell_id        date        time
# 0  /TJNe+Mmtu  2012-05-06  23:04:37.0
# 1  /+cKZKIp41  2012-05-06  23:05:25.0
# 2  /u0FSD+ahi  2012-05-06  23:05:41.0
# 3  +cNeJzsTp3  2012-05-06  23:05:42.0
# 4  051KhYDCpv  2012-05-06  23:06:29.0

# %%
# drop and review  dublcicates
df_cdrcombine = df_cdrcombine.drop_duplicates()
df_cdrcombine.head
# Out:
# <bound method NDFrame.head of         City      Status      Locality Geographical_Zone Zone_Name  \
# NaN   VILLES      STATUS  LOCALISATION        DECOUPZONE  ZONENAME
# 0.0   ADJAME  In Service       ABIDJAN      "Abidjan_EST  AGBANNEW
# 1.0   ADJAME  In Service       ABIDJAN      "Abidjan_EST  AGBANNEW
# 2.0   ADJAME  In Service       ABIDJAN      "Abidjan_EST  AGBANNEW
# 3.0  ASSINIE  In Service     INTERIEUR         Grand-EST  ASSINIE"
# ..       ...         ...           ...               ...       ...
# 4.0      NaN         NaN           NaN               NaN       NaN
# 5.0      NaN         NaN           NaN               NaN       NaN
# 6.0      NaN         NaN           NaN               NaN       NaN
# 7.0      NaN         NaN           NaN               NaN       NaN
# 9.0      NaN         NaN           NaN               NaN       NaN
#
#              Longitude          Latitude     Region  Area     Cell_ID  \
# ...

# %%
#combining the whole table
df_overall = pd.concat([df_cdrcombine,df_combine_cleaned],axis=0)
df_overall.head

# %%
# checking info in the overall table
df_overall.info()

# %% [markdown]
# **DATA** **EXPLORATION**

# %%
df_combine.groupby('cell_id').count().nlargest(5,'product')
# Out:
#             product  value  date_time  cell_on_site  dw_a_number_int  \
# cell_id
# ffa6759bb2     1996   1996       1996          1996             1996
# 03ee801971       75     75         75            75               75
# cc7ce19d6b       65     65         65            65               65
# d22224b2fa       43     43         43            43               43
# b78724d6fc       42     42         42            42               42
#
#             dw_b_number_int  country_a  country_b  site_id  date  time
# cell_id
# ffa6759bb2             1996       1996       1996        0  1996  1996
# 03ee801971               75         75         75       75    75    75
# cc7ce19d6b               65         65         65       65    65    65
# d22224b2fa               43         43         43       43    43    43
# b78724d6fc               42         42         42       42    42    42

# %%
df_combine.groupby('product')['value'].sum()
# Out:
# product
# Voice    312593
# data      17287
# sms       53427
# Name: value, dtype: int64
